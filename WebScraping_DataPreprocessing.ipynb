# %%
import os
import pandas as pd

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome()
driver.get('https://www.redfin.com/')

driver.maximize_window()
elem = driver.find_element("xpath","//button[@class='onetrust-close-btn-handler onetrust-close-btn-ui banner-close-button ot-close-icon']")
elem.click()
elem = driver.find_element("xpath","//input[@title='City, Address, School, Agent, ZIP']")
elem.click()
elem.clear()
elem.send_keys("fremont")
elem.send_keys(Keys.RETURN)
time.sleep(5)
elem = driver.find_element("xpath","//a[@id='download-and-save']")
driver.execute_script("arguments[0].scrollIntoView({behavior: 'auto', block: 'center', inline: 'center'});", elem)
elem.click()
time.sleep(5)

Homepagelink= driver.find_element("xpath","//a[@data-rf-test-id='breadcrumbTitle'][1]")
Homepagelink.click()  
time.sleep(5)
elem = driver.find_element("xpath","//input[@title='City, Address, School, Agent, ZIP']")
elem.click()
elem.clear()
elem.send_keys("san francisco")
elem.send_keys(Keys.RETURN)
time.sleep(10)
elem = driver.find_element("xpath","//a[@id='download-and-save']")
driver.execute_script("arguments[0].scrollIntoView({behavior: 'auto', block: 'center', inline: 'center'});", elem)
elem.click()
time.sleep(5)

Homepagelink= driver.find_element("xpath","//a[@data-rf-test-id='breadcrumbTitle'][1]")
Homepagelink.click()  
time.sleep(5)
elem = driver.find_element("xpath","//input[@title='City, Address, School, Agent, ZIP']")
elem.click()
elem.clear()
elem.send_keys("dublin")
elem.send_keys(Keys.RETURN)
time.sleep(10)
elem = driver.find_element("xpath","//a[@id='download-and-save']")
driver.execute_script("arguments[0].scrollIntoView({behavior: 'auto', block: 'center', inline: 'center'});", elem)
elem.click()
time.sleep(5)

Homepagelink= driver.find_element("xpath","//a[@data-rf-test-id='breadcrumbTitle'][1]")
Homepagelink.click()  
time.sleep(5)
elem = driver.find_element("xpath","//input[@title='City, Address, School, Agent, ZIP']")
elem.click()
elem.clear()
elem.send_keys("san jose")
elem.send_keys(Keys.RETURN)
time.sleep(10)
elem = driver.find_element("xpath","//a[@id='download-and-save']")
driver.execute_script("arguments[0].scrollIntoView({behavior: 'auto', block: 'center', inline: 'center'});", elem)
elem.click()
time.sleep(5)

Homepagelink= driver.find_element("xpath","//a[@data-rf-test-id='breadcrumbTitle'][1]")
Homepagelink.click()  
time.sleep(5)
elem = driver.find_element("xpath","//input[@title='City, Address, School, Agent, ZIP']")
elem.click()
elem.clear()
elem.send_keys("Hayward")
elem.send_keys(Keys.RETURN)
time.sleep(10)
elem = driver.find_element("xpath","//a[@id='download-and-save']")
driver.execute_script("arguments[0].scrollIntoView({behavior: 'auto', block: 'center', inline: 'center'});", elem)
elem.click()
time.sleep(5)

driver.close()

# %%
import os
import pandas as pd

#pass the correct path of Download folder here 
#as this code will take the downloaded .csv files from download folder

files=os.listdir("C:\\Users\\bhosa\\Downloads\\")
mylist=[]
for file in files:
    if file.startswith("redfin_2023"):
        mylist.append(file)

dfs = []
for file_name in mylist:
    df = pd.read_csv("C:\\Users\\bhosa\\Downloads\\"+file_name)
    dfs.append(df)


union_df = pd.concat(dfs, axis=0, ignore_index=True)
union_df
# Out:
#                  SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0              Redfin Data        NaN  Single Family Residential
# 1              Redfin Data        NaN  Single Family Residential
# 2              MLS Listing        NaN  Single Family Residential
# 3              MLS Listing        NaN                  Townhouse
# 4              MLS Listing        NaN                  Townhouse
# ..                     ...        ...                        ...
# 994  New Construction Plan        NaN    Multi-Family (2-4 Unit)
# 995  New Construction Plan        NaN    Multi-Family (2-4 Unit)
# 996  New Construction Plan        NaN    Multi-Family (2-4 Unit)
# 997  New Construction Plan        NaN    Multi-Family (2-4 Unit)
# 998  New Construction Plan        NaN  Single Family Residential
#
#                     ADDRESS     CITY STATE OR PROVINCE ZIP OR POSTAL CODE  \
# 0        39681 Catamaran Ct  Fremont                CA              94538
# 1    37481 Summer Holly Cmn  Fremont                CA              94536
# 2         780 Orangewood Dr  Fremont                CA              94536
# 3         42955 Corte Verde  Fremont                CA         94539-5313
# 4       38590 Royal Ann Cmn  Fremont                CA              94536
# ..                      ...      ...               ...                ...
# 994              Plan 3 WLH  Hayward                CA              94544
# 995              Plan 4 WLH  Hayward                CA              94544
# 996              Plan 2 WLH  Hayward                CA              94544
# 997              Plan 1 WLH  Hayward                CA              94544
# 998                    Lily  Hayward                CA              94544
#
#        PRICE  BEDS  BATHS  ...         STATUS  NEXT OPEN HOUSE START TIME  \
# 0    1300000   3.0    2.0  ...  Pre On-Market                         NaN
# 1    1380000   4.0    2.5  ...  Pre On-Market                         NaN
# 2     900000   3.0    2.0  ...         Active                         NaN
# 3     990000   3.0    1.5  ...         Active                         NaN
# 4     748888   3.0    1.5  ...         Active                         NaN
# ..       ...   ...    ...  ...            ...                         ...
# 994   938190   3.0    3.5  ...         Active                         NaN
# 995   966705   3.0    3.5  ...         Active                         NaN
# 996   860725   2.0    2.5  ...         Active                         NaN
# 997   819310   2.0    2.5  ...         Active                         NaN
# 998  1299000   4.0    3.0  ...         Active                         NaN
#
#      NEXT OPEN HOUSE END TIME  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 994                       NaN
# 995                       NaN
# 996                       NaN
# 997                       NaN
# 998                       NaN
#
#      URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0    https://www.redfin.com/CA/Fremont/39681-Catama...
# 1    https://www.redfin.com/CA/Fremont/37481-Summer...
# 2    https://www.redfin.com/CA/Fremont/780-Orangewo...
# 3    https://www.redfin.com/CA/Fremont/42955-Corte-...
# 4    https://www.redfin.com/CA/Fremont/38590-Royal-...
# ..                                                 ...
# 994  https://www.redfin.com/CA/Hayward/SoHay-Prime/...
# 995  https://www.redfin.com/CA/Hayward/SoHay-Prime/...
# 996  https://www.redfin.com/CA/Hayward/SoHay-Prime/...
# 997  https://www.redfin.com/CA/Hayward/SoHay-Prime/...
# 998  https://www.redfin.com/CA/Hayward/Calluna/Lily...
#
#                                            SOURCE            MLS#  FAVORITE  \
# 0                                     Coming Soon           92185         N
# 1                                     Coming Soon           91889         N
# 2    bridgeMLS, Bay East AOR, or Contra Costa AOR        41025752         N
# 3    bridgeMLS, Bay East AOR, or Contra Costa AOR        41025224         N
# 4    bridgeMLS, Bay East AOR, or Contra Costa AOR        41025667         N
# ..                                            ...             ...       ...
# 994                             NewHomeSource.com  Plan-221799277         N
# 995                             NewHomeSource.com  Plan-221799278         N
# 996                             NewHomeSource.com  Plan-221771200         N
# 997                             NewHomeSource.com  Plan-221771199         N
# 998                             NewHomeSource.com  Plan-222020048         N
#
#     INTERESTED   LATITUDE   LONGITUDE
# 0            Y  37.529339 -121.990033
# 1            Y  37.543647 -122.014818
# 2            Y  37.576227 -121.960576
# 3            Y  37.536959 -121.923693
# 4            Y  37.566879 -121.970475
# ..         ...        ...         ...
# 994          Y  37.630486 -122.050005
# 995          Y  37.628191 -122.052158
# 996          Y  37.628191 -122.052158
# 997          Y  37.628191 -122.052158
# 998          Y  37.626751 -122.070007
#
# [999 rows x 27 columns]

# %% [markdown]
# # Dropping the irrevelant columns

# %%
union_df=union_df.drop(['SOLD DATE','LOT SIZE','HOA/MONTH','ADDRESS','ZIP OR POSTAL CODE','NEXT OPEN HOUSE START TIME','NEXT OPEN HOUSE END TIME','FAVORITE','INTERESTED','URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)'],axis=1)
union_df.head()
# Out:
#      SALE TYPE              PROPERTY TYPE     CITY STATE OR PROVINCE    PRICE  \
# 0  Redfin Data  Single Family Residential  Fremont                CA  1300000
# 1  Redfin Data  Single Family Residential  Fremont                CA  1380000
# 2  MLS Listing  Single Family Residential  Fremont                CA   900000
# 3  MLS Listing                  Townhouse  Fremont                CA   990000
# 4  MLS Listing                  Townhouse  Fremont                CA   748888
#
#    BEDS  BATHS         LOCATION  SQUARE FEET  YEAR BUILT  DAYS ON MARKET  \
# 0   3.0    2.0          Fremont       1067.0      1961.0             7.0
# 1   4.0    2.5          Fremont       1866.0      1998.0            21.0
# 2   3.0    2.0       Niles Area       1120.0      1955.0             1.0
# 3   3.0    1.5  Valle De La Paz       1242.0      1971.0             1.0
# 4   3.0    1.5      Cherry Lane       1180.0      1971.0             2.0
#
#    $/SQUARE FEET         STATUS                                        SOURCE  \
# 0         1218.0  Pre On-Market                                   Coming Soon
# 1          740.0  Pre On-Market                                   Coming Soon
# 2          804.0         Active  bridgeMLS, Bay East AOR, or Contra Costa AOR
# 3          797.0         Active  bridgeMLS, Bay East AOR, or Contra Costa AOR
# 4          635.0         Active  bridgeMLS, Bay East AOR, or Contra Costa AOR
#
#        MLS#   LATITUDE   LONGITUDE
# 0     92185  37.529339 -121.990033
# 1     91889  37.543647 -122.014818
# 2  41025752  37.576227 -121.960576
# 3  41025224  37.536959 -121.923693
# 4  41025667  37.566879 -121.970475

# %%
union_df.columns
# Out:
# Index(['SALE TYPE', 'PROPERTY TYPE', 'CITY', 'STATE OR PROVINCE', 'PRICE',
#        'BEDS', 'BATHS', 'LOCATION', 'SQUARE FEET', 'YEAR BUILT',
#        'DAYS ON MARKET', '$/SQUARE FEET', 'STATUS', 'SOURCE', 'MLS#',
#        'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %% [markdown]
# # Making the shape of the updated data

# %%
union_df.shape
# Out:
# (999, 17)

# %% [markdown]
# # Doing the sum of Null values in the data set

# %%
#checking if any null values
num_missing = union_df.isna().sum()
num_missing
# Out:
# SALE TYPE              0
# PROPERTY TYPE          0
# CITY                   0
# STATE OR PROVINCE      0
# PRICE                  0
# BEDS                  41
# BATHS                 54
# LOCATION               0
# SQUARE FEET           78
# YEAR BUILT           126
# DAYS ON MARKET        62
# $/SQUARE FEET         78
# STATUS                 0
# SOURCE                 0
# MLS#                   0
# LATITUDE               0
# LONGITUDE              0
# dtype: int64

# %%
#droping the null values
union_df=union_df.dropna()

# %%
#checking if any null values

num_missing = union_df.isna().sum()
num_missing
# Out:
# SALE TYPE            0
# PROPERTY TYPE        0
# CITY                 0
# STATE OR PROVINCE    0
# PRICE                0
# BEDS                 0
# BATHS                0
# LOCATION             0
# SQUARE FEET          0
# YEAR BUILT           0
# DAYS ON MARKET       0
# $/SQUARE FEET        0
# STATUS               0
# SOURCE               0
# MLS#                 0
# LATITUDE             0
# LONGITUDE            0
# dtype: int64

# %% [markdown]
# # Drawing a Box Plot to identify the outliers.

# %%
union_df.boxplot(column=['PRICE'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removing Outliers & Ploting the Box Plot Once again

# %%
Q1 = union_df['PRICE'].quantile(0.25)
Q3 = union_df['PRICE'].quantile(0.75)
IQR = Q3 - Q1
df['PRICE'] = df['PRICE'][~((df['PRICE'] < (Q1 - 1.5 * IQR)) |(df['PRICE'] > (Q3 + 1.5 * IQR)))]

df.boxplot(column=['PRICE'])
# Out:
# <AxesSubplot:>

# %%
# write the resulting DataFrame to a CSV file
output_path = "output.csv"
union_df.to_csv(output_path, index=False)

print(f"Successfully wrote DataFrame to {output_path}")
# Out:
# Successfully wrote DataFrame to output.csv
